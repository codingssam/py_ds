# %%
# %load mysettings.py
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=2, suppress=True)

# %matplotlib inline

# %%
import pandas as pd
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.7.3.final.0
# python-bits: 64
# OS: Windows
# OS-release: 10
# machine: AMD64
# processor: Intel64 Family 6 Model 158 Stepping 9, GenuineIntel
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: None.None
#
# pandas: 0.24.2
# pytest: 4.3.1
# pip: 19.0.3
# setuptools: 40.8.0
# Cython: 0.29.6
# numpy: 1.16.2
# scipy: 1.2.1
# pyarrow: 0.11.1
# xarray: None
# IPython: 7.4.0
# sphinx: 1.8.5
# patsy: 0.5.1
# dateutil: 2.8.0
# pytz: 2018.9
# blosc: None
# bottleneck: 1.2.1
# tables: 3.5.1
# numexpr: 2.6.9
# feather: None
# matplotlib: 3.0.3
# openpyxl: 2.6.1
# xlrd: 1.2.0
# xlwt: 1.3.0
# xlsxwriter: 1.1.5
# lxml.etree: 4.3.2
# bs4: 4.7.1
# html5lib: 1.0.1
# sqlalchemy: 1.3.1
# pymysql: None
# psycopg2: None
# jinja2: 2.10
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None
# gcsfs: None

# %%
df = pd.DataFrame(data={'col1': [1, 2], 'col2': [3, 4]})
df.to_parquet('df.parquet.gzip', compression='gzip')
pd.read_parquet('df.parquet.gzip')
# Out:
# C:\Users\ai\Anaconda3\lib\site-packages\pyarrow\pandas_compat.py:114: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   result = infer_dtype(pandas_collection)
# C:\Users\ai\Anaconda3\lib\site-packages\pyarrow\pandas_compat.py:708: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels = getattr(columns, 'labels', None) or [
# C:\Users\ai\Anaconda3\lib\site-packages\pyarrow\pandas_compat.py:735: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return pd.MultiIndex(levels=new_levels, labels=labels, names=columns.names)
# C:\Users\ai\Anaconda3\lib\site-packages\pyarrow\pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels
#    col1  col2
# 0     1     3
# 1     2     4

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
print(mpl.__version__)
print(mpl.__file__)
print(mpl.get_configdir())
print(mpl.get_cachedir())
print(mpl.matplotlib_fname())
# Out:
# 3.0.3
# C:\Users\ai\Anaconda3\lib\site-packages\matplotlib\__init__.py
# C:\Users\ai\.matplotlib
# C:\Users\ai\.matplotlib
# C:\Users\ai\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
fm.fontManager.ttflist
# Out:
# [<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>,
#  <Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal bold normal>,
#  <Font 'cmr10' (cmr10.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal bold normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal bold normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal bold normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal bold normal>,
#  <Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal bold normal>,
#  <Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal bold normal>,
#  <Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal bold normal>,
#  <Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>,
#  <Font 'cmb10' (cmb10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal bold normal>,
#  <Font 'cmex10' (cmex10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal bold normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal bold normal>,
#  <Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>,
#  <Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>,
#  <Font 'cmss10' (cmss10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>,
#  <Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal bold normal>,
#  <Font 'Georgia' (georgiai.ttf) italic normal 400 normal>,
#  <Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>,
#  <Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>,
#  <Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>,
#  <Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal 400 normal>,
#  <Font 'Constantia' (constan.ttf) normal normal 400 normal>,
#  <Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (seguibli.ttf) italic normal 400 normal>,
#  <Font 'Calibri' (calibri.ttf) normal normal 400 normal>,
#  <Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (segoeuil.ttf) normal normal 400 normal>,
#  <Font 'Arial' (arialbi.ttf) italic normal bold normal>,
#  <Font 'Comic Sans MS' (comicbd.ttf) normal normal bold normal>,
#  <Font 'Courier New' (courbd.ttf) normal normal bold normal>,
#  <Font 'Constantia' (constanz.ttf) italic normal bold normal>,
#  <Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>,
#  <Font 'Segoe UI' (segoeuisl.ttf) normal normal 400 normal>,
#  <Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>,
#  <Font 'Cambria' (cambriaz.ttf) italic normal bold normal>,
#  <Font 'Myanmar Text' (mmrtextb.ttf) normal normal bold normal>,
#  <Font 'Palatino Linotype' (palab.ttf) normal normal bold normal>,
#  <Font 'Constantia' (constani.ttf) italic normal 400 normal>,
#  <Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>,
#  <Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>,
#  <Font 'Franklin Gothic Medium' (framd.ttf) normal normal medium normal>,
#  <Font 'Candara' (Candaral.ttf) normal normal light normal>,
#  <Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>,
#  <Font 'Arial' (arialbd.ttf) normal normal bold normal>,
#  <Font 'Cambria' (cambriai.ttf) italic normal 400 normal>,
#  <Font 'Candara' (Candarali.ttf) italic normal light normal>,
#  <Font 'Verdana' (verdanaz.ttf) italic normal bold normal>,
#  <Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (seguisbi.ttf) italic normal semibold normal>,
#  <Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>,
#  <Font 'Malgun Gothic' (malgunsl.ttf) normal normal light normal>,
#  <Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal bold normal>,
#  <Font 'Webdings' (webdings.ttf) normal normal 400 normal>,
#  <Font 'Calibri' (calibrii.ttf) italic normal 400 normal>,
#  <Font 'Cambria' (cambriab.ttf) normal normal bold normal>,
#  <Font 'Candara' (Candarai.ttf) italic normal 400 normal>,
#  <Font 'Segoe UI' (seguili.ttf) italic normal light normal>,
#  <Font 'Times New Roman' (times.ttf) normal normal roman normal>,
#  <Font 'Verdana' (verdanai.ttf) italic normal 400 normal>,
#  <Font 'Corbel' (corbelli.ttf) italic normal light normal>,
#  <Font 'Candara' (Candarab.ttf) normal normal bold normal>,
#  <Font 'Wingdings' (wingding.ttf) normal normal 400 normal>,
#  <Font 'Calibri' (calibril.ttf) normal normal light normal>,
#  <Font 'Courier New' (couri.ttf) italic normal 400 normal>,
#  <Font 'Gadugi' (gadugib.ttf) normal normal bold normal>,
#  <Font 'Corbel' (corbel.ttf) normal normal 400 normal>,
#  <Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>,
#  <Font 'Constantia' (constanb.ttf) normal normal bold normal>,
#  <Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>,
#  <Font 'Times New Roman' (timesbd.ttf) normal normal roman normal>,
#  <Font 'Symbol' (symbol.ttf) normal normal 400 normal>,
#  <Font 'Calibri' (calibrib.ttf) normal normal bold normal>,
#  <Font 'Arial' (ariali.ttf) italic normal 400 normal>,
#  <Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>,
#  <Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>,
#  <Font 'Arial' (ariblk.ttf) normal normal black normal>,
#  <Font 'Segoe Print' (segoeprb.ttf) normal normal bold normal>,
#  <Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>,
#  <Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>,
#  <Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal bold normal>,
#  <Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>,
#  <Font 'Georgia' (georgiab.ttf) normal normal bold normal>,
#  <Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>,
#  <Font 'Times New Roman' (timesi.ttf) italic normal roman normal>,
#  <Font 'Candara' (Candara.ttf) normal normal 400 normal>,
#  <Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>,
#  <Font 'Malgun Gothic' (malgunbd.ttf) normal normal bold normal>,
#  <Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>,
#  <Font 'Times New Roman' (timesbi.ttf) italic normal roman normal>,
#  <Font 'Nirmala UI' (NirmalaS.ttf) normal normal light normal>,
#  <Font 'Georgia' (georgia.ttf) normal normal 400 normal>,
#  <Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>,
#  <Font 'Consolas' (consolab.ttf) normal normal bold normal>,
#  <Font 'Segoe UI' (seguisli.ttf) italic normal light normal>,
#  <Font 'Marlett' (marlett.ttf) normal normal 400 normal>,
#  <Font 'Consolas' (consolaz.ttf) italic normal bold normal>,
#  <Font 'Segoe UI' (seguisb.ttf) normal normal 400 normal>,
#  <Font 'Consolas' (consolai.ttf) italic normal 400 normal>,
#  <Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>,
#  <Font 'Comic Sans MS' (comicz.ttf) italic normal bold normal>,
#  <Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>,
#  <Font 'Consolas' (consola.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (seguibl.ttf) normal normal 400 normal>,
#  <Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>,
#  <Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>,
#  <Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>,
#  <Font 'Verdana' (verdanab.ttf) normal normal bold normal>,
#  <Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>,
#  <Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>,
#  <Font 'Candara' (Candaraz.ttf) italic normal bold normal>,
#  <Font 'Franklin Gothic Medium' (framdit.ttf) italic normal medium normal>,
#  <Font 'Corbel' (corbelb.ttf) normal normal bold normal>,
#  <Font 'Microsoft Tai Le' (taileb.ttf) normal normal bold normal>,
#  <Font 'Corbel' (corbelz.ttf) italic normal bold normal>,
#  <Font 'Verdana' (verdana.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (segoeuiz.ttf) italic normal bold normal>,
#  <Font 'Trebuchet MS' (trebucbd.ttf) normal normal bold normal>,
#  <Font 'Corbel' (corbeli.ttf) italic normal 400 normal>,
#  <Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>,
#  <Font 'Georgia' (georgiaz.ttf) italic normal bold normal>,
#  <Font 'Palatino Linotype' (palabi.ttf) italic normal bold normal>,
#  <Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>,
#  <Font 'Trebuchet MS' (trebucbi.ttf) italic normal bold normal>,
#  <Font 'Courier New' (courbi.ttf) italic normal bold normal>,
#  <Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>,
#  <Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>,
#  <Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>,
#  <Font 'Segoe Script' (segoescb.ttf) normal normal bold normal>,
#  <Font 'Calibri' (calibriz.ttf) italic normal bold normal>,
#  <Font 'Calibri' (calibrili.ttf) italic normal light normal>,
#  <Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>,
#  <Font 'Nirmala UI' (NirmalaB.ttf) normal normal bold normal>,
#  <Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>,
#  <Font 'Impact' (impact.ttf) normal normal 400 normal>,
#  <Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>,
#  <Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>,
#  <Font 'Courier New' (cour.ttf) normal normal 400 normal>,
#  <Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>,
#  <Font 'Corbel' (corbell.ttf) normal normal light normal>,
#  <Font 'Arial' (arial.ttf) normal normal 400 normal>]

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
[(f.name, f.fname) for f in fm.fontManager.ttflist]
# Out:
# [('cmmi10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmmi10.ttf'),
#  ('DejaVu Sans',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Bold.ttf'),
#  ('STIXSizeFourSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFourSymBol.ttf'),
#  ('cmr10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmr10.ttf'),
#  ('STIXSizeTwoSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizTwoSymReg.ttf'),
#  ('STIXNonUnicode',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUniBol.ttf'),
#  ('DejaVu Sans',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-BoldOblique.ttf'),
#  ('DejaVu Sans',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Oblique.ttf'),
#  ('STIXSizeOneSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizOneSymBol.ttf'),
#  ('DejaVu Sans Mono',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono.ttf'),
#  ('STIXSizeOneSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizOneSymReg.ttf'),
#  ('DejaVu Serif',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif-Bold.ttf'),
#  ('DejaVu Serif',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif-BoldItalic.ttf'),
#  ('DejaVu Serif Display',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerifDisplay.ttf'),
#  ('DejaVu Sans',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'),
#  ('STIXGeneral',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneral.ttf'),
#  ('STIXSizeThreeSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizThreeSymBol.ttf'),
#  ('STIXGeneral',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralItalic.ttf'),
#  ('STIXNonUnicode',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUniBolIta.ttf'),
#  ('STIXGeneral',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralBol.ttf'),
#  ('STIXSizeFiveSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFiveSymReg.ttf'),
#  ('cmb10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmb10.ttf'),
#  ('DejaVu Sans Mono',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-Oblique.ttf'),
#  ('STIXGeneral',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXGeneralBolIta.ttf'),
#  ('cmex10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmex10.ttf'),
#  ('DejaVu Sans Mono',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-Bold.ttf'),
#  ('STIXSizeThreeSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizThreeSymReg.ttf'),
#  ('DejaVu Serif',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif-Italic.ttf'),
#  ('DejaVu Serif',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSerif.ttf'),
#  ('STIXNonUnicode',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUni.ttf'),
#  ('STIXSizeTwoSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizTwoSymBol.ttf'),
#  ('STIXSizeFourSym',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXSizFourSymReg.ttf'),
#  ('cmtt10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmtt10.ttf'),
#  ('cmss10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmss10.ttf'),
#  ('DejaVu Sans Display',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansDisplay.ttf'),
#  ('STIXNonUnicode',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\STIXNonUniIta.ttf'),
#  ('cmsy10',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\cmsy10.ttf'),
#  ('DejaVu Sans Mono',
#   'C:\\Users\\ai\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-BoldOblique.ttf'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgiai.ttf'),
#  ('Microsoft New Tai Lue', 'C:\\Windows\\Fonts\\ntailu.ttf'),
#  ('Microsoft Tai Le', 'C:\\Windows\\Fonts\\taile.ttf'),
#  ('Segoe Script', 'C:\\Windows\\Fonts\\segoesc.ttf'),
#  ('Leelawadee UI', 'C:\\Windows\\Fonts\\LeelUIsl.ttf'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constan.ttf'),
#  ('Myanmar Text', 'C:\\Windows\\Fonts\\mmrtext.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguibli.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibri.ttf'),
#  ('Segoe MDL2 Assets', 'C:\\Windows\\Fonts\\segmdl2.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuil.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\arialbi.ttf'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comicbd.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\courbd.ttf'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constanz.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\palai.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuisl.ttf'),
#  ('Microsoft PhagsPa', 'C:\\Windows\\Fonts\\phagspa.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambriaz.ttf'),
#  ('Myanmar Text', 'C:\\Windows\\Fonts\\mmrtextb.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\palab.ttf'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constani.ttf'),
#  ('Segoe UI Symbol', 'C:\\Windows\\Fonts\\seguisym.ttf'),
#  ('Microsoft Sans Serif', 'C:\\Windows\\Fonts\\micross.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuib.ttf'),
#  ('Franklin Gothic Medium', 'C:\\Windows\\Fonts\\framd.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candaral.ttf'),
#  ('Ebrima', 'C:\\Windows\\Fonts\\ebrima.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\arialbd.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambriai.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candarali.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdanaz.ttf'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebuc.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguisbi.ttf'),
#  ('Gadugi', 'C:\\Windows\\Fonts\\gadugi.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Microsoft New Tai Lue', 'C:\\Windows\\Fonts\\ntailub.ttf'),
#  ('Webdings', 'C:\\Windows\\Fonts\\webdings.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrii.ttf'),
#  ('Cambria', 'C:\\Windows\\Fonts\\cambriab.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candarai.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguili.ttf'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\times.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdanai.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbelli.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candarab.ttf'),
#  ('Wingdings', 'C:\\Windows\\Fonts\\wingding.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibril.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\couri.ttf'),
#  ('Gadugi', 'C:\\Windows\\Fonts\\gadugib.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbel.ttf'),
#  ('Tahoma', 'C:\\Windows\\Fonts\\tahomabd.ttf'),
#  ('Constantia', 'C:\\Windows\\Fonts\\constanb.ttf'),
#  ('Ink Free', 'C:\\Windows\\Fonts\\Inkfree.ttf'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\timesbd.ttf'),
#  ('Symbol', 'C:\\Windows\\Fonts\\symbol.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrib.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ariali.ttf'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comici.ttf'),
#  ('Lucida Console', 'C:\\Windows\\Fonts\\lucon.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\ariblk.ttf'),
#  ('Segoe Print', 'C:\\Windows\\Fonts\\segoeprb.ttf'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comic.ttf'),
#  ('Segoe Print', 'C:\\Windows\\Fonts\\segoepr.ttf'),
#  ('Microsoft PhagsPa', 'C:\\Windows\\Fonts\\phagspab.ttf'),
#  ('Microsoft Himalaya', 'C:\\Windows\\Fonts\\himalaya.ttf'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgiab.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuii.ttf'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\timesi.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candara.ttf'),
#  ('Tahoma', 'C:\\Windows\\Fonts\\tahoma.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('SimSun-ExtB', 'C:\\Windows\\Fonts\\simsunb.ttf'),
#  ('Times New Roman', 'C:\\Windows\\Fonts\\timesbi.ttf'),
#  ('Nirmala UI', 'C:\\Windows\\Fonts\\NirmalaS.ttf'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgia.ttf'),
#  ('Lucida Sans Unicode', 'C:\\Windows\\Fonts\\l_10646.ttf'),
#  ('Segoe UI Historic', 'C:\\Windows\\Fonts\\seguihis.ttf'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consolab.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguisli.ttf'),
#  ('Marlett', 'C:\\Windows\\Fonts\\marlett.ttf'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consolaz.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguisb.ttf'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consolai.ttf'),
#  ('Bahnschrift', 'C:\\Windows\\Fonts\\bahnschrift.ttf'),
#  ('Comic Sans MS', 'C:\\Windows\\Fonts\\comicz.ttf'),
#  ('Mongolian Baiti', 'C:\\Windows\\Fonts\\monbaiti.ttf'),
#  ('Consolas', 'C:\\Windows\\Fonts\\consola.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\seguibl.ttf'),
#  ('Javanese Text', 'C:\\Windows\\Fonts\\javatext.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Gabriola', 'C:\\Windows\\Fonts\\Gabriola.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdanab.ttf'),
#  ('HoloLens MDL2 Assets', 'C:\\Windows\\Fonts\\holomdl2.ttf'),
#  ('Leelawadee UI', 'C:\\Windows\\Fonts\\LeelaUIb.ttf'),
#  ('Candara', 'C:\\Windows\\Fonts\\Candaraz.ttf'),
#  ('Franklin Gothic Medium', 'C:\\Windows\\Fonts\\framdit.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbelb.ttf'),
#  ('Microsoft Tai Le', 'C:\\Windows\\Fonts\\taileb.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbelz.ttf'),
#  ('Verdana', 'C:\\Windows\\Fonts\\verdana.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeuiz.ttf'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebucbd.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbeli.ttf'),
#  ('MV Boli', 'C:\\Windows\\Fonts\\mvboli.ttf'),
#  ('Georgia', 'C:\\Windows\\Fonts\\georgiaz.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\palabi.ttf'),
#  ('Segoe UI', 'C:\\Windows\\Fonts\\segoeui.ttf'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebucbi.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\courbi.ttf'),
#  ('Segoe UI Emoji', 'C:\\Windows\\Fonts\\seguiemj.ttf'),
#  ('Palatino Linotype', 'C:\\Windows\\Fonts\\pala.ttf'),
#  ('Sylfaen', 'C:\\Windows\\Fonts\\sylfaen.ttf'),
#  ('Segoe Script', 'C:\\Windows\\Fonts\\segoescb.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibriz.ttf'),
#  ('Calibri', 'C:\\Windows\\Fonts\\calibrili.ttf'),
#  ('Trebuchet MS', 'C:\\Windows\\Fonts\\trebucit.ttf'),
#  ('Nirmala UI', 'C:\\Windows\\Fonts\\NirmalaB.ttf'),
#  ('Leelawadee UI', 'C:\\Windows\\Fonts\\LeelawUI.ttf'),
#  ('Impact', 'C:\\Windows\\Fonts\\impact.ttf'),
#  ('Ebrima', 'C:\\Windows\\Fonts\\ebrimabd.ttf'),
#  ('Microsoft Yi Baiti', 'C:\\Windows\\Fonts\\msyi.ttf'),
#  ('Courier New', 'C:\\Windows\\Fonts\\cour.ttf'),
#  ('Nirmala UI', 'C:\\Windows\\Fonts\\Nirmala.ttf'),
#  ('Corbel', 'C:\\Windows\\Fonts\\corbell.ttf'),
#  ('Arial', 'C:\\Windows\\Fonts\\arial.ttf')]

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")
flights = sns.load_dataset("flights")

# %%
x = iris.petal_length.values
sns.kdeplot(x);

# %%
sns.distplot(x, kde=True, rug=True);

# %%
sns.countplot(x="class", data=titanic);

# %%
sns.countplot(x="day", data=tips);

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris);

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris, kind="kde");

# %%
sns.pairplot(iris);

# %%
sns.pairplot(iris, hue="species", markers=["o", "s", "D"]);

# %%
titanic_size = titanic.pivot_table(index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size, cmap=sns.light_palette("green", as_cmap=True), 
            annot=True, fmt="d");

# %%
sns.barplot(x="day", y="total_bill", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
sns.swarmplot(x="day", y="total_bill", data=tips);

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.stripplot(x="day", y="total_bill", hue="sex", data=tips, jitter=True)
plt.legend(loc=1);
# Location String   Location Code
# ===============   =============
# 'best'            0
# 'upper right'     1
# 'upper left'      2
# 'lower left'      3
# 'lower right'     4
# 'right'           5
# 'center left'     6
# 'center right'    7
# 'lower center'    8
# 'upper center'    9
# 'center'          10
# ===============   =============

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)
plt.legend(loc=1);

# %%
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True);

# %%
sns.stripplot(x="day", y="total_bill", hue="sex",
              data=tips, jitter=True, dodge=True);

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips, dodge=True);

# %%
flights_passengers = flights.pivot("month", "year", "passengers")
sns.heatmap(flights_passengers, annot=True, fmt="d", linewidths=1);
